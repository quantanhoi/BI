# %%
import pandas as pd

try:
    df = pd.read_csv('SalesData.csv', encoding='utf-8', sep=';', on_bad_lines='skip')
    print("File loaded successfully.")
except FileNotFoundError:
    print("File not found. Check the path.")
except pd.errors.ParserError as e:
    print(f"Parsing error: {e}. Try adjusting sep or encoding.")
# Out:
# File loaded successfully.

# %%
print(df.head(10))
print(df['SalesOrg'].unique())
print(df['Country'].unique())
print(df[['Product', 'ProdDescr']].drop_duplicates())
df.columns.tolist()
# Out:
#    OrderNumber  OrderItem      Date  Customer      CustDescr      City  \
# 0       100001         10  01.01.07     17000  Cruiser Bikes  Hannover
# 1       100001         20  01.01.07     17000  Cruiser Bikes  Hannover
# 2       100001         30  01.01.07     17000  Cruiser Bikes  Hannover
# 3       100001         40  01.01.07     17000  Cruiser Bikes  Hannover
# 4       100002         10  03.01.07     15000  Bavaria Bikes   München
# 5       100002         20  03.01.07     15000  Bavaria Bikes   München
# 6       100002         30  03.01.07     15000  Bavaria Bikes   München
# 7       100002         40  03.01.07     15000  Bavaria Bikes   München
# 8       100002         50  03.01.07     15000  Bavaria Bikes   München
# 9       100002         60  03.01.07     15000  Bavaria Bikes   München
#
#   SalesOrg Country   Product                           ProdDescr  ...  \
# 0     DN00      DE  PRTR1000     Professional Touring Bike-Black  ...
# 1     DN00      DE  DXTR1000           Deluxe Touring Bike-Black  ...
# 2     DN00      DE  DXRD2000                  Road Bike Alu SRAM  ...
# 3     DN00      DE  ORWN1000         Women's Off Road Bike Fully  ...
# 4     DS00      DE  PRTR1000     Professional Touring Bike-Black  ...
# 5     DS00      DE  ORHT2000  Men's Off Road Bike Hard Tail SRAM  ...
# 6     DS00      DE  SHRT1000                             T-shirt  ...
# 7     DS00      DE  RHMT1000                         Road Helmet  ...
# 8     DS00      DE  FAID1000                       First Aid Kit  ...
# 9     DS00      DE  PRRD1000            Road Bike Carbon Shimano  ...
#
#        CatDescr Division SalesQuantity  UnitOfMeasure   Revenue Currency  \
# 0  Touring Bike       BI             4             ST  10669,84      EUR
# 1  Touring Bike       BI             8             ST  20005,92      EUR
# 2      Roadbike       BI             2             ST   2750,82      EUR
# 3  Offroad Bike       BI             5             ST  10419,75      EUR
# 4  Touring Bike       BI             4             ST  10669,84      EUR
# 5  Offroad Bike       BI             7             ST    9919,6      EUR
# 6    Accessoire       AS             6             ST    150,06      EUR
# 7    Accessoire       AS             1             ST     41,68      EUR
# 8    Accessoire       AS            21             ST    700,22      EUR
# 9      Roadbike       BI             7             ST  23340,24      EUR
#
#   Discount RevenueUSD DiscountUSD CostsUSD
# 0    320,1   14080,02      422,41     8320
# 1   600,18      26400         792    15600
# 2    82,52    3630,01      108,89     2046
# 3   312,59      13750       412,5     7500
# 4   533,49   14052,21      702,61     8320
# 5   495,98   13064,14      653,21     7140
# 6      7,5     197,63        9,88       90
# 7     2,09      54,89        2,75       25
# 8    35,01     922,19       46,11      420
# 9  1167,01   30739,15     1536,96    17360
#
# [10 rows x 21 columns]
# ['DN00' 'DS00' 'UE00' 'UW00']
# ['DE' 'GER' 'US' 'USA']
#         Product                              ProdDescr
# 0      PRTR1000        Professional Touring Bike-Black
# 1      DXTR1000              Deluxe Touring Bike-Black
# 2      DXRD2000                     Road Bike Alu SRAM
# 3      ORWN1000            Women's Off Road Bike Fully
# 5      ORHT2000     Men's Off Road Bike Hard Tail SRAM
# 6      SHRT1000                                T-shirt
# 7      RHMT1000                            Road Helmet
# 8      FAID1000                          First Aid Kit
# 9      PRRD1000               Road Bike Carbon Shimano
# 13     DXTR2000             Deluxe Touring Bike-Silver
# 15     DXTR3000                Deluxe Touring Bike-Red
# 16     PUMP1000                               Air Pump
# 18     OHMT1000                        Off Road Helmet
# 21     DXRD1000                  Road Bike Alu Shimano
# 28     CAGE1000                      Water Bottle Cage
# 29     ORMN1000              Men's Off Road Bike Fully
# 31     BOTL1000                           Water Bottle
# 33     PRTR2000       Professional Touring Bike-Silver
# 40     KPAD1000                              Knee Pads
# 45     RKIT1000                             Repair Kit
# 47     PRRD2000                  Road Bike Carbon SRAM
# 51     ORHT1000  Men's Off Road Bike Hard Tail Shimano
# 76     EPAD1000                             Elbow Pads
# 106    PRTR3000          Professional Touring Bike-Red
# 184    PRRD3000            Road Bike Carbon Campagnolo
# 375    CITY1000                               City Max
# 487    FXGR1000                             Edel Fixie
# 19555  ELBK1000                        E-Bike Tailwind
# 58121  HVBD1000                             Hoverboard
# ['OrderNumber',
#  'OrderItem',
#  'Date',
#  'Customer',
#  'CustDescr',
#  'City',
#  'SalesOrg',
#  'Country',
#  'Product',
#  'ProdDescr',
#  'ProdCat',
#  'CatDescr',
#  'Division',
#  'SalesQuantity',
#  'UnitOfMeasure',
#  'Revenue',
#  'Currency',
#  'Discount',
#  'RevenueUSD',
#  'DiscountUSD',
#  'CostsUSD']
